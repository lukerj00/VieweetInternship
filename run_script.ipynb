# %%
#import azureml.core
#from azureml.core import Workspace, Datastore
#from azureml.data.data_reference import DataReference

# Load the workspace from the saved config file
#ws = Workspace.from_config()
#print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.22.0 to work with willlaml

# %%
# Data reference to training/ validation data on datastore
#default_ds = ws.get_default_datastore()

#ds = Datastore.get(ws, datastore_name='imatod_datasets')
#data_ref = DataReference(
#        datastore=ds,
#        data_reference_name="data",
#        path_on_datastore = 'vieweet360/panoramas/')

# model_ds = Datastore.get(ws, datastore_name='imatod_models')
# model_data_ref = DataReference(
#        datastore=model_ds,
#        data_reference_name="model",
#        path_on_datastore = '')

# %%
# from azureml.core import Environment
# from azureml.core.conda_dependencies import CondaDependencies
# from azureml.core.compute import AmlCompute, ComputeTarget

# ****Select which compute resource to use****
# options: room-classifier-dev, CPU-cluster, GPU-cluster
# REMEMBER TO START COMPUTE INSTANCE

# target = 'CPU'

# if 'GPU' in target:
#     env = Environment.get(ws,'rc_GPU',6)
#     cluster_name = 'GPU-cluster'
# else:
#     env = Environment.get(ws,'rc_CPU')
#     cluster_name = 'room-classification-dev'

# compute_target = ws.compute_targets[cluster_name]

# %%
#from azureml.core import Experiment, ScriptRunConfig
#from azureml.widgets import RunDetails
#from azureml.tensorboard import Tensorboard

#Set the script parameters
script_params = [
    '--data_dir',   str(data_ref),
    '--model_dir',  str(model_data_ref),    
    '--log_dir',    './logs', 
    '--classifier', 'full',
    '--batch_size', 1,
    '--dummy',
    '--incl_metadata'
]

src = ScriptRunConfig(source_directory='.',
                      arguments=script_params,
                      compute_target = compute_target,
                      environment = env,
                      script='test_multi.py')
src.run_config.data_references = {data_ref.data_reference_name: data_ref.to_config(),
                                  model_data_ref.data_reference_name: model_data_ref.to_config()} 

experiment = Experiment(workspace = ws, name ='rc_test')
run = experiment.submit(config=src, 
                        tags={'classifier':'full',
                              'training context':'unbalanced, unweighted, augmented',
                              'codex':'full_wmeta',
                              'model':'ResNet10',
                              'image size':'64x128',
                              'dataset':'full'                                                                                             ,
                        })

RunDetails(run).show()
run.wait_for_completion()
# Out:
# Submitting /mnt/batch/tasks/shared/LS_root/mounts/clusters/room-classification-dev/code/Users/william.alexander/room-classification-2/test directory for run. The size of the directory >= 25 MB, so it can take a few minutes.
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
# {'runId': 'rc_test_1626798212_636e29f9',
#  'target': 'room-classification-dev',
#  'status': 'Finalizing',
#  'startTimeUtc': '2021-07-20T16:23:56.010057Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'c6695176-b9e4-4bde-a554-ed3840ff46cd',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json',
#   'azureml.RuntimeType': '',
#   'azureml.git.repository_uri': 'git@gitlab.com:walexand3r/room-classification-2.git',
#   'mlflow.source.git.repoURL': 'git@gitlab.com:walexand3r/room-classification-2.git',
#   'azureml.git.branch': 'master',
# ...

# %%
# Creating/ adding to existing environment
#from azureml.core import Environment
#from azureml.core.conda_dependencies import CondaDependencies

# env = Environment.from_conda_specification(name='room-classifier-env', file_path='.azureml/room-classifier-env.yml')
# env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
# env.docker.enabled = True # Use a docker container

env = Environment.get(ws,'rc_GPU')
env = env.clone('rc_GPU')

env.save_to_directory('./env/GPU-env', overwrite=True)

# Change conda dependencies in file, then run below

# %%
# Register env
env = Environment.load_from_directory('./env/GPU-env')
env.register(ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20201112.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#         "NCCL_TREE_THRESHOLD": "0"
#     },
#     "inferencingStackVersion": null,
#     "name": "rc_GPU",
#     "python": {
#         "baseCondaEnvironment": null,
# ...
